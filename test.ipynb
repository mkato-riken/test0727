# %%
import pandas as pd

# %% [markdown]
# あれ？？？

# %%
df = pd.read_csv("slack_2021_07_27.csv")

# %%
df
# Out:
#     ID       アカウント種別    アカウント作成日  アクティブ日数  投稿されたメッセージ数  チャンネルに投稿されたメッセージ数  \
# 0    1  シングルチャンネルゲスト  2020/05/07        0            0                  0
# 1    2  シングルチャンネルゲスト  2020/03/10        0            0                  0
# 2    3          メンバー  2020/05/29        0            0                  0
# 3    4          メンバー  2020/06/28        0            0                  0
# 4    4  シングルチャンネルゲスト  2020/04/24        0            0                  0
# 5    5  シングルチャンネルゲスト  2021/01/12        2            0                  0
# 6    6  シングルチャンネルゲスト  2020/03/31        2            3                  3
# 7    7  シングルチャンネルゲスト  2021/01/12        2            0                  0
# 8    8  シングルチャンネルゲスト  2020/02/21        2            3                  3
# 9    9  シングルチャンネルゲスト  2021/01/12        3            0                  0
# 10  10  シングルチャンネルゲスト  2020/03/24        3            0                  0
# 11  11          メンバー  2020/03/10        4            0                  0
# ...

# %%
df_tmp= df.copy()

# %%
df_tmp.query('アクティブ日数 > 5')
# Out:
#     ID       アカウント種別    アカウント作成日  アクティブ日数  投稿されたメッセージ数  チャンネルに投稿されたメッセージ数  \
# 24  24          メンバー  2020/05/09       11            1                  1
# 25  25          メンバー  2020/01/07       13           15                  0
# 26  26          メンバー  2021/04/30       14          207                 16
# 27  27          メンバー  2021/05/07       14           11                 11
# 28  28          メンバー  2020/08/17       14            4                  2
# 29  29  シングルチャンネルゲスト  2020/03/25       15           27                  0
# 30  30          メンバー  2021/05/06       15           17                  7
# 31  31          オーナー  2020/01/07       15          211                 47
# 32  32          メンバー  2020/08/05       17           79                 34
# 33  33          メンバー  2020/04/02       19           22                  7
# 34  34          メンバー  2021/06/01       20           30                  2
# 35  35           管理者  2020/03/30       23          518                 25
# ...
